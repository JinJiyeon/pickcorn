# %%
import json


with open('movies.json') as json_file:
    json_data = json.load(json_file)

# %%
movie_list = []
needkey = ['genres', 'id', 'overview', 'title', 'vote_average', 'vote_count']
for data in json_data:
    movie = {
        'model': 'movies.movie',
        'fields':{
            'title': data.get('title'),
            'id': data.get('id'),
            'overview': data.get('overview'),
            # 
            'genres': data.get('genres'),
            'vote_average': data.get('vote_average'),
            'vote_count': data.get('vote_count')
        }
    }
    movie_list.append(movie)

# %%
with open('movies_abs.json', 'w', encoding='utf-8') as f:
    json.dump(movie_list, f)

# %%
movie_genre_list = []
needkey = ['genres', 'id', 'overview', 'title', 'vote_average', 'vote_count']
for data in json_data:
    print(data.get('genres'))
    # movie_list.append(movie)
# Out:
#  99, "name": "Documentary"}]
# [{"id": 27, "name": "Horror"}, {"id": 53, "name": "Thriller"}, {"id": 80, "name": "Crime"}]
# [{"id": 27, "name": "Horror"}, {"id": 53, "name": "Thriller"}]
# [{"id": 18, "name": "Drama"}]
# [{"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# [{"id": 27, "name": "Horror"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}, {"id": 80, "name": "Crime"}]
# [{"id": 27, "name": "Horror"}, {"id": 9648, "name": "Mystery"}, {"id": 53, "name": "Thriller"}]
# [{"id": 27, "name": "Horror"}]
# [{"id": 37, "name": "Western"}]
# [{"id": 99, "name": "Documentary"}]
# [{"id": 99, "name": "Documentary"}]
# [{"id": 18, "name": "Drama"}]
# [{"id": 9648, "name": "Mystery"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# [{"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 10402, "name": "Music"}]
# [{"id": 18, "name": "Drama"}]
# [{"id": 18, "name": "Drama"}]
# ...
